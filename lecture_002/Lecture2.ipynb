# %%
# !ls
# Out:
# sample_data

# %%
# Google Drive 마운트하기
from google.colab import drive
drive.mount('/content/drive')

# 특정 디렉토리로 이동하기
import os

# 예: My Drive 내의 'project' 폴더로 이동

project_path = '/content/drive/MyDrive/GPU-MODE/lectures/lecture_002'
# 디렉토리 존재 여부 확인 후 이동
if os.path.exists(project_path):
    os.chdir(project_path)
    print(f"현재 작업 디렉토리: {os.getcwd()}")
else:
    print(f"디렉토리가 존재하지 않습니다: {project_path}")

# 현재 디렉토리 내용 확인
print("\n현재 디렉토리 내용:")
print(os.listdir())
# Out:
# Mounted at /content/drive
# 현재 작업 디렉토리: /content/drive/MyDrive/GPU-MODE/lectures/lecture_002
#
# 현재 디렉토리 내용:
# ['README.md', 'cuda_mode_lecture2.pptx', 'mean_filter', 'rgb_to_grayscale', 'vector_addition', 'Lecture2']

# %%
# !pip install ninja
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 5.8 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_002/mean_filter
# !python mean_filter.py
# Out:
# /content/drive/MyDrive/GPU-MODE/lectures/lecture_002/mean_filter
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Input image: torch.Size([3, 606, 517]) torch.uint8
# Output image: torch.Size([3, 606, 517]) torch.uint8

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_002/rgb_to_grayscale
# !python rgb_to_grayscale.py
# Out:
# /content/drive/MyDrive/GPU-MODE/lectures/lecture_002/rgb_to_grayscale
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# mean: tensor(80.4631, device='cuda:0')
# Input image: torch.Size([606, 517, 3]) torch.uint8
# Output image: torch.Size([606, 517, 1]) torch.uint8
# mean tensor(74.3289, device='cuda:0')

# %%
# !nvidia-smi
# !nvcc --version
# Out:
# Fri Mar 21 15:14:22 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_002/vector_addition/
# !make clean
# !make
# !./vector_addition
# Out:
# /content/drive/MyDrive/GPU-MODE/lectures/lecture_002/vector_addition
# rm -rf *.o vector_addition
# nvcc -c -o vector_addition.o vector_addition.cu -O3 -arch=sm_75 --compiler-options -Wall
# nvcc vector_addition.o -o vector_addition -lcudart
#    0.000,    1.001,    2.002,    3.003,    4.004,    5.005,    6.006,    7.007,    8.008,    9.009,
#   10.010,   11.011,   12.012,   13.013,   14.014,   15.015,   16.016,   17.017,   18.018,   19.019,
#   20.020,   21.021,   22.022,   23.023,   24.024,   25.025,   26.026,   27.027,   28.028,   29.029,
#   30.030,   31.031,   32.032,   33.033,   34.034,   35.035,   36.036,   37.037,   38.038,   39.039,
#   40.040,   41.041,   42.042,   43.043,   44.044,   45.045,   46.046,   47.047,   48.048,   49.049,
#   50.050,   51.051,   52.052,   53.053,   54.054,   55.055,   56.056,   57.057,   58.058,   59.059,
#   60.060,   61.061,   62.062,   63.063,   64.064,   65.065,   66.066,   67.067,   68.068,   69.069,
# ...
