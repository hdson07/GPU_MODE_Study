# %%
# Google Drive 마운트하기
from google.colab import drive
drive.mount('/content/drive')

# 특정 디렉토리로 이동하기
import os

# 예: My Drive 내의 'project' 폴더로 이동

project_path = '/content/drive/MyDrive/GPU-MODE/lectures/lecture_001'
# 디렉토리 존재 여부 확인 후 이동
if os.path.exists(project_path):
    os.chdir(project_path)
    print(f"현재 작업 디렉토리: {os.getcwd()}")
else:
    print(f"디렉토리가 존재하지 않습니다: {project_path}")

# 현재 디렉토리 내용 확인
print("\n현재 디렉토리 내용:")
print(os.listdir())
# Out:
# Mounted at /content/drive
# 현재 작업 디렉토리: /content/drive/MyDrive/GPU-MODE/lectures/lecture_001
#
# 현재 디렉토리 내용:
# ['pytorch_square.py', 'triton_profile', 'nsys_square.py', 'test.py', 'ncu_logs', 'hello_load_inline.py', 'main.py', 'numba_square.py', 'load_inline.py', 'CUDA MODE_ Lecture 1.pdf', 'README.md', 'tmp', 'load_inline_cuda', 'build', 'setup.py', 'my_module.cpython-311-x86_64-linux-gnu.so', 'pt_profiler.py', '.ipynb_checkpoints', 'breakpoint_square.py', 'triton_square.py', 'square() performance.png', 'square() performance.csv', 'results.html', 'triton-square-profile.py']

# %%
# !pip install ninja

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_001
# !python pt_profiler.py
# Out:
# /content
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                           ProfilerStep*         0.00%       0.000us         0.00%       0.000us       0.000us     226.081ms       125.60%     226.081ms     113.041ms             2
#                                             aten::copy_         0.01%     122.261us         9.77%     174.209ms      87.104ms     173.478ms        96.38%     173.478ms      86.739ms             2
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     173.478ms        96.38%     173.478ms      86.739ms             2
#                                               aten::pow         0.01%     186.509us         0.01%     260.427us     130.213us       6.524ms         3.62%       6.524ms       3.262ms             2
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us       6.524ms         3.62%       6.524ms       3.262ms             2
#                                           ProfilerStep*         2.59%      46.149ms        99.83%        1.781s     890.410ms       0.000us         0.00%     180.002ms      90.001ms             2
#                                             aten::randn         0.00%      70.747us        87.45%        1.560s     779.993ms       0.000us         0.00%       0.000us       0.000us             2
#                                             aten::empty         0.00%      54.901us         0.00%      54.901us      27.451us       0.000us         0.00%       0.000us       0.000us             2
#                                           aten::normal_        87.44%        1.560s        87.44%        1.560s     779.930ms       0.000us         0.00%       0.000us       0.000us             2
#                                                aten::to         0.00%      67.397us         9.78%     174.412ms      43.603ms       0.000us         0.00%     173.478ms      43.369ms             4
#                                          aten::_to_copy         0.00%      67.132us         9.77%     174.344ms      87.172ms       0.000us         0.00%     173.478ms      86.739ms             2
#                                     aten::empty_strided         0.00%      68.377us         0.00%      68.377us      34.189us       0.000us         0.00%       0.000us       0.000us             2
#                                         cudaMemcpyAsync         9.76%     174.032ms         9.76%     174.032ms      87.016ms       0.000us         0.00%       0.000us       0.000us             2
#                                   cudaStreamSynchronize         0.00%      54.235us         0.00%      54.235us      27.118us       0.000us         0.00%       0.000us       0.000us             2
#                                            aten::square         0.00%      14.754us         0.02%     275.181us     137.590us       0.000us         0.00%       6.524ms       3.262ms             2
#                                       aten::result_type         0.00%       4.246us         0.00%       4.246us       2.123us       0.000us         0.00%       0.000us       0.000us             2
#                                        cudaLaunchKernel         0.00%      68.171us         0.00%      68.171us      34.086us       0.000us         0.00%       0.000us       0.000us             2
#                                   cudaDeviceSynchronize         0.17%       3.023ms         0.17%       3.023ms       3.023ms       0.000us         0.00%       0.000us       0.000us             1
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 1.784s
# Self CUDA time total: 180.002ms

# %% [markdown]
# # STEP1 #
# python, C++ linking을 이용한 컴파일 실행 예제
#
# 1. python inline source code 정의
# 2. source code 분리, python Compiler & Run
# 3. .so (Library) build & Run
#
# \# Reference.
#
# GPU-MODE/lectures/lecture_001/tmp
#
# GPU-MODE/lectures/lecture_001/hello_load_inline.py

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_001
# !python hello_load_inline.py
# Out:
# /content/drive/MyDrive/GPU-MODE/lectures/lecture_001
# Emitting ninja build file ./tmp/build.ninja...
# Building extension module my_module...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF main.o.d -DTORCH_EXTENSION_NAME=my_module -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -c /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/main.cpp -o main.o
# [2/2] c++ main.o -shared -L/usr/local/lib/python3.11/dist-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o my_module.so
# Loading extension module my_module...
# Hello World!

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp
# Out:
# /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp

# %%
from torch.utils.cpp_extension import load

#Using JIT build
# 이 한 줄로 컴파일과 로딩을 동시에 수행
my_module = load(
    name="my_module",
    sources=["main.cpp"],
    verbose=True  # 컴파일 과정 출력
)

# 바로 사용 가능
result = my_module.hello_world()
print(result)
# Out:
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu124/my_module...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu124/my_module/build.ninja...
# Building extension module my_module...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Hello World!
# Loading extension module my_module...

# %% [markdown]
# # Optional Build Code (Using LD_LABRARY_PATH) #

# %%
import torch
import os

# PyTorch 라이브러리 경로 찾기
torch_lib_path = os.path.join(os.path.dirname(torch.__file__), 'lib')
print(f"PyTorch 라이브러리 경로: {torch_lib_path}")

# 환경 변수 설정
os.environ['LD_LIBRARY_PATH'] = torch_lib_path + ':' + os.environ.get('LD_LIBRARY_PATH', '')

# 확인
print(f"설정된 LD_LIBRARY_PATH: {os.environ['LD_LIBRARY_PATH']}")
# Out:
# PyTorch 라이브러리 경로: /usr/local/lib/python3.11/dist-packages/torch/lib
# 설정된 LD_LIBRARY_PATH: /usr/local/lib/python3.11/dist-packages/torch/lib:/usr/local/lib/python3.11/dist-packages/torch/lib:/usr/local/lib/python3.11/dist-packages/torch/lib:/usr/local/lib/python3.11/dist-packages/torch/lib:/usr/lib64-nvidia

# %%
# %%writefile setup.py
from setuptools import setup
from torch.utils.cpp_extension import CppExtension, BuildExtension
import torch
import os

include_dirs = [
    os.path.join(os.path.dirname(torch.__file__), 'include'),
    os.path.join(os.path.dirname(torch.__file__), 'include/torch/csrc/api/include')
]

setup(
    name="my_module",
    ext_modules=[
        CppExtension(
            name="my_module",
            sources=["/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/main.cpp"],
            include_dirs=include_dirs,
        )
    ],
    cmdclass={
        "build_ext": BuildExtension
    }
)
# Out:
# Overwriting setup.py

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# building 'my_module' extension
# Emitting ninja build file /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/main.o -L/usr/local/lib/python3.11/dist-packages/torch/lib -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -o build/lib.linux-x86_64-cpython-311/my_module.cpython-311-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-cpython-311/my_module.cpython-311-x86_64-linux-gnu.so ->

# %%
#To check my_module.so file
# !ls -al
# Out:
# total 10607
# drwx------ 4 root root    4096 Mar 14 01:54 build
# -rw------- 1 root root    1133 Mar 14 01:50 build.ninja
# -rw------- 1 root root     209 Mar 11 13:42 main.cpp
# -rw------- 1 root root 1777808 Mar 11 13:42 main.o
# -rwx------ 1 root root 9074240 Mar 14 04:02 my_module.cpython-311-x86_64-linux-gnu.so
# -rw------- 1 root root     112 Mar 11 13:42 .ninja_deps
# -rw------- 1 root root     129 Mar 11 13:42 .ninja_log
# -rw------- 1 root root     591 Mar 14 04:01 setup.py

# %%
import my_module

# hello_world 함수 호출
result = my_module.hello_world()
print(result)
# Out:
# Hello World!

# %% [markdown]
# # STEP2 #
# **Code Description**
#
# main.cpp:
# - 역할: PyTorch C++ 확장 모듈의 진입점
# - 주요 구성:
#   - #include <torch/extension.h>: PyTorch 확장 모듈 헤더 포함
#   - torch::Tensor square_matrix(torch::Tensor matrix): 함수 선언
#   - PYBIND11_MODULE: Python으로 C++ 함수를 노출시키는 매크로
#   - m.def("square_matrix", ...): Python에서 호출할 함수명 정의
#
# cuda.cu:
# - 역할: CUDA 커널 및 C++ 인터페이스 구현
# - 주요 구성:
#   - __global__ void square_matrix_kernel: CUDA 커널 정의
#       - blockIdx, threadIdx: CUDA 스레드 좌표
#     - 행렬의 각 요소를 제곱하는 로직
#   - torch::Tensor square_matrix: 파이썬에서 호출할 C++ 함수 구현
#       - 스레드/블록 구성 설정
#     - CUDA 커널 실행
#     - 결과 반환
#
# **Build & Run**
#   1. C++ 컴파일:
#     - main.cpp 파일이 C++ 컴파일러로 컴파일됨
#     - PyTorch 헤더 포함하여 오브젝트 파일 생성
#   2. CUDA 컴파일:
#     - cuda.cu 파일이 NVCC로 컴파일됨
#     - CUDA 커널 코드를 실행 가능한 형태로 변환
#   3. 링킹:
#     - 두 오브젝트 파일을 PyTorch, CUDA 라이브러리와 링크
#     - 동적 라이브러리(.so) 생성
#   4. Python에서 로드:
#     - 생성된 .so 파일을 Python 모듈로 로드
#     - Python에서 C++/CUDA 함수 호출 가능

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_001
# Out:
# /content/drive/MyDrive/GPU-MODE/lectures/lecture_001

# %%
#using python file, python 파일 내 모든 소스코드 정의. 파일 내부에서 C++/CUDA 코드 컴파일 및 정의
# !python load_inline.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# tensor([[ 1.,  4.,  9.],
#         [16., 25., 36.]], device='cuda:0')

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda
# Out:
# /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda

# %%
import torch
from torch.utils.cpp_extension import load

# JIT 컴파일 실행 - 외부 소스 파일 사용
module = load(
    name="square_matrix_extension",
    sources=["/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/main.cpp",
             "/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/cuda.cu"],
    verbose=True,
    with_cuda=True
)

# 모듈 테스트 실행
a = torch.tensor([[1., 2., 3.], [4., 5., 6.]], device='cuda')
result = module.square_matrix(a)
print(result)
# Out:
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu124/square_matrix_extension/build.ninja...
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Building extension module square_matrix_extension...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module square_matrix_extension...
# tensor([[ 1.,  4.,  9.],
#         [16., 25., 36.]], device='cuda:0')

# %%
# %%writefile setup.py
from setuptools import setup
from torch.utils.cpp_extension import CUDAExtension, BuildExtension
import torch
import os

# 필요한 include 디렉토리 경로
include_dirs = [
    os.path.join(os.path.dirname(torch.__file__), 'include'),
    os.path.join(os.path.dirname(torch.__file__), 'include/torch/csrc/api/include')
]

setup(
    name="square_matrix_extension",
    ext_modules=[
        CUDAExtension(
            name="square_matrix_extension",
            sources=[
                "/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/main.cpp",
                "/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/cuda.cu"
            ],
            include_dirs=include_dirs,
            # 필요한 경우 CUDA 아키텍처 지정
            extra_compile_args={
                'cxx': ['-D_GLIBCXX_USE_CXX11_ABI=0'],
                'nvcc': ['-D_GLIBCXX_USE_CXX11_ABI=0']
            }
        )
    ],
    cmdclass={
        "build_ext": BuildExtension
    }
)
# Out:
# Overwriting setup.py

# %%
# !python setup.py build_ext --inplace
#To check my_module.so file
# !ls -al
# Out:
# running build_ext
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.4). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'square_matrix_extension' extension
# creating /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Emitting ninja build file /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/cuda.o.d -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.11 -c -c /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/cuda.cu -o /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -D_GLIBCXX_USE_CXX11_ABI=0 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=square_matrix_extension -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75 -std=c++17
# [2/2] c++ -MMD -MF /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/main.o.d -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.11 -c -c /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/main.cpp -o /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/main.o -D_GLIBCXX_USE_CXX11_ABI=0 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=square_matrix_extension -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/cuda.o /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/tmp/build/temp.linux-x86_64-cpython-311/content/drive/MyDrive/GPU-MODE/lectures/lecture_001/load_inline_cuda/main.o -L/usr/local/lib/python3.11/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-311/square_matrix_extension.cpython-311-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-cpython-311/square_matrix_extension.cpython-311-x86_64-linux-gnu.so ->

# %%
import square_matrix_extension

a = torch.tensor([[1., 2., 3.], [4., 5., 6.]], device='cuda')
result = square_matrix_extension.square_matrix(a)
print(result)
# Out:
# total 19828
# drwx------ 4 root root    4096 Mar 14 01:54 build
# -rw------- 1 root root    1357 Mar 14 04:38 build.ninja
# -rw------- 1 root root     209 Mar 11 13:42 main.cpp
# -rw------- 1 root root 1777808 Mar 11 13:42 main.o
# -rwx------ 1 root root 9074240 Mar 14 04:53 my_module.cpython-311-x86_64-linux-gnu.so
# -rw------- 1 root root     112 Mar 11 13:42 .ninja_deps
# -rw------- 1 root root     129 Mar 11 13:42 .ninja_log
# -rw------- 1 root root    1014 Mar 14 04:57 setup.py
# -rwx------ 1 root root 9442232 Mar 14 04:58 square_matrix_extension.cpython-311-x86_64-linux-gnu.so
# tensor([[ 1.,  4.,  9.],
#         [16., 25., 36.]], device='cuda:0')

# %% [markdown]
# # Triton Optimization #
# Triton을 이용하여 CUDA GPU, Square 연산 최적화
# 1. Triton Kernel Code 정의
#   - @triton.jit : CUDA Code 컴파일
#   - row_idx = tl.program_id(0) : 인스턴스 ID load, 행처리 최적화
#     GPU에서는 1개의 block이 1개의 행을 담당하며 병령성을 확보
#   - row 시작 주소, 인덱스 배열 생성, 메모리 포인터 계산
#   - tl.load() : GPU에서 SRAM으로 로드 & Masking
#   - Operation
#   - Save : 출력 위치 계산, 및 저장
# 2. Python Interface ( square 함수 ) 정의
#   - 함수 정의
#   - BLOCK_SIZE = triton.next_power_of_2(n_cols): 입력 크기에 맞는 최적화된 연산 단위 계산
#   - num_warps : 32개의 스레드로 구성된 GPU 실행 단위
#     - 워프수를 늘리면 많은 스레드가 한개의 행을 처리
#     - 큰 사이즈 행렬일수록 많은 병렬처리가 필요
#   - 커널 실행 및 결과 반환
# 3. 검증 테스트
#   - UT
#   - benchmark test

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_001
# !python triton_square.py
# Out:
# /content
# Figure(640x480)
# square() performance:
#         N       Triton  Torch (native)  Torch (compiled)
# 0  6400.0  1428.266277      246.691253        251.577740
# 1  6528.0  1430.794464      240.110348        242.884678
# 2  6656.0  1467.171136      237.391379        243.063518
# 3  6784.0  1471.003849      237.303274        242.895666
# 4  6912.0  1418.840958      237.744381        243.059340

# %% [markdown]
# ### NCU를 이용한 square 성능 Profile ###
# - Block Size를 변경하며 square 연산을 단순 반복
# - nuc를 붙혀서 각 인스턴스에 대한 성능 분석
# - Memory TP 향상을 위한 간단한 최적화

# %%
# %cd /content/drive/MyDrive/GPU-MODE/lectures/lecture_001
print("### ORG Square ###")
# !python triton-square-profile.py

print("### OPT Square ###")
# !python triton-square-opt.py
# Out:
# /content
# ### ORG Square ###
# Triton Square 연산 프로파일링 시작
#
# 크기: 1024 요소
# 평균 실행 시간: 0.0404 ms
# 처리량: 0.0254 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 8192 요소
# 평균 실행 시간: 0.0373 ms
# 처리량: 0.2195 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 65536 요소
# 평균 실행 시간: 0.0372 ms
# 처리량: 1.7636 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 524288 요소
# 평균 실행 시간: 0.0384 ms
# 처리량: 13.6688 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 4194304 요소
# 평균 실행 시간: 0.1406 ms
# 처리량: 29.8390 십억 요소/초
# 최대 오차: 0.0
#
# Triton Square 연산 프로파일링 완료
# ### OPT Square ###
# Triton Square 연산 프로파일링 시작
#
# 크기: 1024 요소
# 평균 실행 시간: 0.0396 ms
# 처리량: 0.0259 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 8192 요소
# 평균 실행 시간: 0.0383 ms
# 처리량: 0.2141 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 65536 요소
# 평균 실행 시간: 0.0371 ms
# 처리량: 1.7674 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 524288 요소
# 평균 실행 시간: 0.0381 ms
# 처리량: 13.7644 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 4194304 요소
# 평균 실행 시간: 0.1404 ms
# 처리량: 29.8686 십억 요소/초
# 최대 오차: 0.0
#
# Triton Square 연산 프로파일링 완료

# %%
# !ncu -o profile_result --set full python triton-square-profile.py
# Out:
# Triton Square 연산 프로파일링 시작
#
# 크기: 1024 요소
# ==PROF== Connected to process 1570 (/usr/bin/python3.11)
# ==PROF== Profiling "distribution_elementwise_grid..." - 0: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 1: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 2: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 3: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 4: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 5: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 6: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 7: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 8: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 9: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 10: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 11: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 12: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 13: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 14: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 15: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 16: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 17: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 18: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 19: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 20: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 21: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 22: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 23: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 24: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 25: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 26: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 27: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 28: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 29: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 30: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 31: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 32: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 33: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 34: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 35: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 36: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 37: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 38: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 39: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 40: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 41: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 42: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 43: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 44: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 45: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 46: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 47: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 48: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 49: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 50: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 51: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 52: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 53: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 54: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 55: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 56: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 57: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 58: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 59: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 60: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 61: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 62: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 63: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 64: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 65: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 66: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 67: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 68: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 69: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 70: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 71: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 72: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 73: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 74: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 75: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 76: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 77: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 78: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 79: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 80: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 81: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 82: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 83: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 84: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 85: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 86: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 87: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 88: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 89: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 90: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 91: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 92: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 93: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 94: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 95: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 96: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 97: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 98: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 99: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 100: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 101: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 102: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 103: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 104: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 105: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 106: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 107: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 108: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 109: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 110: 0%....50%....100% - 30 passes
# 평균 실행 시간: 395.3530 ms
# 처리량: 0.0000 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 8192 요소
# ==PROF== Profiling "distribution_elementwise_grid..." - 111: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 112: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 113: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 114: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 115: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 116: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 117: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 118: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 119: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 120: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 121: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 122: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 123: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 124: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 125: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 126: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 127: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 128: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 129: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 130: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 131: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 132: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 133: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 134: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 135: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 136: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 137: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 138: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 139: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 140: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 141: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 142: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 143: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 144: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 145: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 146: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 147: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 148: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 149: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 150: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 151: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 152: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 153: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 154: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 155: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 156: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 157: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 158: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 159: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 160: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 161: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 162: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 163: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 164: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 165: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 166: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 167: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 168: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 169: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 170: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 171: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 172: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 173: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 174: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 175: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 176: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 177: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 178: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 179: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 180: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 181: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 182: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 183: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 184: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 185: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 186: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 187: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 188: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 189: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 190: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 191: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 192: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 193: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 194: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 195: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 196: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 197: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 198: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 199: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 200: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 201: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 202: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 203: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 204: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 205: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 206: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 207: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 208: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 209: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 210: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 211: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 212: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 213: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 214: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 215: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 216: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 217: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 218: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 219: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 220: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 221: 0%....50%....100% - 30 passes
# 평균 실행 시간: 381.0183 ms
# 처리량: 0.0000 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 65536 요소
# ==PROF== Profiling "distribution_elementwise_grid..." - 222: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 223: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 224: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 225: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 226: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 227: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 228: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 229: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 230: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 231: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 232: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 233: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 234: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 235: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 236: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 237: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 238: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 239: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 240: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 241: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 242: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 243: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 244: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 245: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 246: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 247: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 248: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 249: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 250: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 251: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 252: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 253: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 254: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 255: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 256: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 257: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 258: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 259: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 260: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 261: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 262: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 263: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 264: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 265: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 266: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 267: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 268: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 269: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 270: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 271: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 272: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 273: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 274: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 275: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 276: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 277: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 278: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 279: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 280: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 281: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 282: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 283: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 284: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 285: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 286: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 287: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 288: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 289: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 290: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 291: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 292: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 293: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 294: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 295: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 296: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 297: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 298: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 299: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 300: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 301: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 302: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 303: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 304: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 305: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 306: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 307: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 308: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 309: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 310: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 311: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 312: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 313: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 314: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 315: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 316: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 317: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 318: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 319: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 320: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 321: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 322: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 323: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 324: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 325: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 326: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 327: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 328: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 329: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 330: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 331: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 332: 0%....50%....100% - 30 passes
# 평균 실행 시간: 381.2839 ms
# 처리량: 0.0002 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 524288 요소
# ==PROF== Profiling "distribution_elementwise_grid..." - 333: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 334: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 335: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 336: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 337: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 338: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 339: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 340: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 341: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 342: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 343: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 344: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 345: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 346: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 347: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 348: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 349: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 350: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 351: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 352: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 353: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 354: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 355: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 356: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 357: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 358: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 359: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 360: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 361: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 362: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 363: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 364: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 365: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 366: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 367: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 368: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 369: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 370: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 371: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 372: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 373: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 374: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 375: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 376: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 377: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 378: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 379: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 380: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 381: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 382: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 383: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 384: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 385: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 386: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 387: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 388: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 389: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 390: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 391: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 392: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 393: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 394: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 395: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 396: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 397: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 398: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 399: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 400: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 401: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 402: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 403: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 404: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 405: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 406: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 407: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 408: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 409: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 410: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 411: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 412: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 413: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 414: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 415: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 416: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 417: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 418: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 419: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 420: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 421: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 422: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 423: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 424: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 425: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 426: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 427: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 428: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 429: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 430: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 431: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 432: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 433: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 434: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 435: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 436: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 437: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 438: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 439: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 440: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 441: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 442: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 443: 0%....50%....100% - 30 passes
# 평균 실행 시간: 386.1578 ms
# 처리량: 0.0014 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 4194304 요소
# ==PROF== Profiling "distribution_elementwise_grid..." - 444: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 445: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 446: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 447: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 448: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 449: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 450: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 451: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 452: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 453: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 454: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 455: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 456: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 457: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 458: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 459: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 460: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 461: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 462: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 463: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 464: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 465: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 466: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 467: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 468: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 469: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 470: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 471: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 472: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 473: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 474: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 475: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 476: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 477: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 478: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 479: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 480: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 481: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 482: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 483: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 484: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 485: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 486: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 487: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 488: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 489: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 490: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 491: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 492: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 493: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 494: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 495: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 496: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 497: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 498: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 499: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 500: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 501: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 502: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 503: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 504: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 505: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 506: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 507: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 508: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 509: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 510: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 511: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 512: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 513: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 514: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 515: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 516: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 517: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 518: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 519: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 520: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 521: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 522: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 523: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 524: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 525: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 526: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 527: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 528: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 529: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 530: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 531: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 532: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 533: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 534: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 535: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 536: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 537: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 538: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 539: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 540: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 541: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 542: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 543: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 544: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 545: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 546: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 547: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 548: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 549: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 550: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 551: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 552: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 553: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 554: 0%....50%....100% - 31 passes
# 평균 실행 시간: 402.8984 ms
# 처리량: 0.0104 십억 요소/초
# 최대 오차: 0.0
#
# Triton Square 연산 프로파일링 완료
# ==PROF== Disconnected from process 1570
# ==PROF== Report: /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/profile_result.ncu-rep

# %%
# !ncu -o profile_result --set full python triton-square-opt.py
# Out:
# Triton Square 연산 프로파일링 시작
#
# 크기: 1024 요소
# ==PROF== Connected to process 25497 (/usr/bin/python3.11)
# ==PROF== Profiling "distribution_elementwise_grid..." - 0: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 1: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 2: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 3: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 4: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 5: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 6: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 7: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 8: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 9: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 10: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 11: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 12: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 13: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 14: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 15: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 16: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 17: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 18: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 19: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 20: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 21: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 22: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 23: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 24: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 25: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 26: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 27: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 28: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 29: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 30: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 31: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 32: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 33: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 34: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 35: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 36: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 37: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 38: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 39: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 40: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 41: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 42: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 43: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 44: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 45: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 46: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 47: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 48: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 49: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 50: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 51: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 52: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 53: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 54: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 55: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 56: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 57: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 58: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 59: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 60: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 61: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 62: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 63: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 64: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 65: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 66: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 67: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 68: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 69: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 70: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 71: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 72: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 73: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 74: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 75: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 76: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 77: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 78: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 79: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 80: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 81: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 82: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 83: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 84: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 85: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 86: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 87: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 88: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 89: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 90: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 91: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 92: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 93: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 94: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 95: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 96: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 97: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 98: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 99: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 100: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 101: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 102: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 103: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 104: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 105: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 106: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 107: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 108: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 109: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 110: 0%....50%....100% - 30 passes
# 평균 실행 시간: 393.6718 ms
# 처리량: 0.0000 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 8192 요소
# ==PROF== Profiling "distribution_elementwise_grid..." - 111: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 112: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 113: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 114: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 115: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 116: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 117: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 118: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 119: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 120: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 121: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 122: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 123: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 124: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 125: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 126: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 127: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 128: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 129: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 130: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 131: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 132: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 133: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 134: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 135: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 136: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 137: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 138: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 139: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 140: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 141: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 142: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 143: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 144: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 145: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 146: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 147: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 148: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 149: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 150: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 151: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 152: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 153: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 154: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 155: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 156: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 157: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 158: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 159: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 160: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 161: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 162: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 163: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 164: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 165: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 166: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 167: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 168: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 169: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 170: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 171: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 172: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 173: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 174: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 175: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 176: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 177: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 178: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 179: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 180: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 181: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 182: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 183: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 184: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 185: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 186: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 187: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 188: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 189: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 190: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 191: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 192: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 193: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 194: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 195: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 196: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 197: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 198: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 199: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 200: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 201: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 202: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 203: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 204: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 205: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 206: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 207: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 208: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 209: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 210: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 211: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 212: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 213: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 214: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 215: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 216: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 217: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 218: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 219: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 220: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 221: 0%....50%....100% - 30 passes
# 평균 실행 시간: 379.6655 ms
# 처리량: 0.0000 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 65536 요소
# ==PROF== Profiling "distribution_elementwise_grid..." - 222: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 223: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 224: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 225: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 226: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 227: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 228: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 229: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 230: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 231: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 232: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 233: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 234: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 235: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 236: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 237: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 238: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 239: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 240: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 241: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 242: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 243: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 244: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 245: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 246: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 247: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 248: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 249: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 250: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 251: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 252: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 253: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 254: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 255: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 256: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 257: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 258: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 259: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 260: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 261: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 262: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 263: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 264: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 265: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 266: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 267: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 268: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 269: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 270: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 271: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 272: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 273: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 274: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 275: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 276: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 277: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 278: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 279: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 280: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 281: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 282: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 283: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 284: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 285: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 286: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 287: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 288: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 289: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 290: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 291: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 292: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 293: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 294: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 295: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 296: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 297: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 298: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 299: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 300: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 301: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 302: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 303: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 304: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 305: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 306: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 307: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 308: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 309: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 310: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 311: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 312: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 313: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 314: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 315: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 316: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 317: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 318: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 319: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 320: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 321: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 322: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 323: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 324: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 325: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 326: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 327: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 328: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 329: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 330: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 331: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 332: 0%....50%....100% - 30 passes
# 평균 실행 시간: 382.0590 ms
# 처리량: 0.0002 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 524288 요소
# ==PROF== Profiling "distribution_elementwise_grid..." - 333: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 334: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 335: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 336: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 337: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 338: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 339: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 340: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 341: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 342: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 343: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 344: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 345: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 346: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 347: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 348: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 349: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 350: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 351: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 352: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 353: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 354: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 355: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 356: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 357: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 358: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 359: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 360: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 361: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 362: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 363: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 364: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 365: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 366: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 367: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 368: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 369: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 370: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 371: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 372: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 373: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 374: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 375: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 376: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 377: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 378: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 379: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 380: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 381: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 382: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 383: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 384: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 385: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 386: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 387: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 388: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 389: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 390: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 391: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 392: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 393: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 394: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 395: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 396: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 397: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 398: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 399: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 400: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 401: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 402: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 403: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 404: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 405: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 406: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 407: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 408: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 409: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 410: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 411: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 412: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 413: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 414: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 415: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 416: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 417: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 418: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 419: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 420: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 421: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 422: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 423: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 424: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 425: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 426: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 427: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 428: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 429: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 430: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 431: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 432: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 433: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 434: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 435: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 436: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 437: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 438: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 439: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 440: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 441: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 442: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 443: 0%....50%....100% - 30 passes
# 평균 실행 시간: 384.8150 ms
# 처리량: 0.0014 십억 요소/초
# 최대 오차: 0.0
#
# 크기: 4194304 요소
# ==PROF== Profiling "distribution_elementwise_grid..." - 444: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 445: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 446: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 447: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 448: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 449: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 450: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 451: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 452: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 453: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 454: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 455: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 456: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 457: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 458: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 459: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 460: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 461: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 462: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 463: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 464: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 465: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 466: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 467: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 468: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 469: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 470: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 471: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 472: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 473: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 474: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 475: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 476: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 477: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 478: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 479: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 480: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 481: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 482: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 483: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 484: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 485: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 486: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 487: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 488: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 489: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 490: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 491: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 492: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 493: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 494: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 495: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 496: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 497: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 498: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 499: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 500: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 501: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 502: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 503: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 504: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 505: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 506: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 507: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 508: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 509: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 510: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 511: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 512: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 513: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 514: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 515: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 516: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 517: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 518: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 519: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 520: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 521: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 522: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 523: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 524: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 525: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 526: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 527: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 528: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 529: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 530: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 531: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 532: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 533: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 534: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 535: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 536: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 537: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 538: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 539: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 540: 0%....50%....100% - 30 passes
# ==PROF== Profiling "square_kernel" - 541: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 542: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 543: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 544: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 545: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 546: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 547: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 548: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 549: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 550: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 551: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 552: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 553: 0%....50%....100% - 31 passes
# ==PROF== Profiling "square_kernel" - 554: 0%....50%....100% - 31 passes
# 평균 실행 시간: 402.0754 ms
# 처리량: 0.0104 십억 요소/초
# 최대 오차: 0.0
#
# Triton Square 연산 프로파일링 완료
# ==PROF== Disconnected from process 25497
# ==PROF== Report: /content/drive/MyDrive/GPU-MODE/lectures/lecture_001/profile_result.ncu-rep
